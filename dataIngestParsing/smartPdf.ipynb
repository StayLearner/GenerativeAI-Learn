# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from typing import List
from langchain_core.documents import Document

class SmartPDFProcessor:
    """Advanced PDF processing with error handling and data cleaning"""

    def __init__(self, chunk_size=1000, chunk_overlap=100):
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap
        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size, 
            chunk_overlap=chunk_overlap, 
            separators=["\n\n", "\n", " ", ""] 
        )

    def process_pdf(self, pdf_path: str) -> List[Document]:
        """Process PDF with smart chunking and metadata enrichment"""

        loader = PyPDFLoader(pdf_path)
        pages = loader.load()
        print(f"PyPDFLoader found {len(pages)} pages.") 

        processed_chunks = []

        for page_num, page in enumerate(pages):
        
            cleaned_text = self.cleanText(page.page_content)
             
            print(f"page details {page} page content {page.page_content}")
            print(f"Page {page_num + 1} char count: {len(cleaned_text.strip())}")

            # SKIP if empty, otherwise process
            if len(cleaned_text.strip()) < 10:
                continue  # Skip this page

           
            chunks = self.text_splitter.create_documents(
                texts=[cleaned_text],
                metadatas=[{
                    "page": page_num + 1,
                    "total_pages": len(pages),
                    "source": pdf_path,
                    "chunk_method": "SmartPDFProcesor",
                    "character_count": len(cleaned_text)
                }]
            )
            processed_chunks.extend(chunks)

        return processed_chunks

    # This is now a method of the class (added 'self')
    def cleanText(self, text):
        """Cleans up text by removing extra spaces and fixing ligatures."""
        text = " ".join(text.split())  # Remove extra spaces

        # 5. Fixed ligatures 
        text = text.replace("ﬁ", "fi")
        text = text.replace("ﬂ", "fl")

        return text

# --- Main execution ---
preprocessor = SmartPDFProcessor()

# Process a PDF file
try:

    chunks = preprocessor.process_pdf("data/pdf/data.pdf")
    print(f"Created {len(chunks)} chunks")


except Exception as e:
    print(f"Error processing PDF: {e}")
# Out:
# PyPDFLoader found 211 pages.
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 0, 'page_label': '1'} page content
# Page 1 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 1, 'page_label': '2'} page content
# Page 2 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 2, 'page_label': '3'} page content
# Page 3 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 3, 'page_label': '4'} page content
# Page 4 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 4, 'page_label': '5'} page content
# Page 5 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 5, 'page_label': '6'} page content
# Page 6 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 6, 'page_label': '7'} page content
# Page 7 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 7, 'page_label': '8'} page content
# Page 8 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 8, 'page_label': '9'} page content
# Page 9 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 9, 'page_label': '10'} page content
# Page 10 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 10, 'page_label': '11'} page content
# Page 11 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 11, 'page_label': '12'} page content
# Page 12 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 12, 'page_label': '13'} page content
# Page 13 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 13, 'page_label': '14'} page content
# Page 14 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 14, 'page_label': '15'} page content
# Page 15 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 15, 'page_label': '16'} page content
# Page 16 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 16, 'page_label': '17'} page content
# Page 17 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 17, 'page_label': '18'} page content
# Page 18 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 18, 'page_label': '19'} page content
# Page 19 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 19, 'page_label': '20'} page content
# Page 20 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 20, 'page_label': '21'} page content
# Page 21 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 21, 'page_label': '22'} page content
# Page 22 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 22, 'page_label': '23'} page content
# Page 23 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 23, 'page_label': '24'} page content
# Page 24 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 24, 'page_label': '25'} page content
# Page 25 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 25, 'page_label': '26'} page content
# Page 26 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 26, 'page_label': '27'} page content
# Page 27 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 27, 'page_label': '28'} page content
# Page 28 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 28, 'page_label': '29'} page content
# Page 29 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 29, 'page_label': '30'} page content
# Page 30 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 30, 'page_label': '31'} page content
# Page 31 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 31, 'page_label': '32'} page content
# Page 32 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 32, 'page_label': '33'} page content
# Page 33 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 33, 'page_label': '34'} page content
# Page 34 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 34, 'page_label': '35'} page content
# Page 35 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 35, 'page_label': '36'} page content
# Page 36 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 36, 'page_label': '37'} page content
# Page 37 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 37, 'page_label': '38'} page content
# Page 38 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 38, 'page_label': '39'} page content
# Page 39 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 39, 'page_label': '40'} page content
# Page 40 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 40, 'page_label': '41'} page content
# Page 41 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 41, 'page_label': '42'} page content
# Page 42 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 42, 'page_label': '43'} page content
# Page 43 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 43, 'page_label': '44'} page content
# Page 44 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 44, 'page_label': '45'} page content
# Page 45 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 45, 'page_label': '46'} page content
# Page 46 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 46, 'page_label': '47'} page content
# Page 47 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 47, 'page_label': '48'} page content
# Page 48 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 48, 'page_label': '49'} page content
# Page 49 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 49, 'page_label': '50'} page content
# Page 50 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 50, 'page_label': '51'} page content
# Page 51 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 51, 'page_label': '52'} page content
# Page 52 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 52, 'page_label': '53'} page content
# Page 53 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 53, 'page_label': '54'} page content
# Page 54 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 54, 'page_label': '55'} page content
# Page 55 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 55, 'page_label': '56'} page content
# Page 56 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 56, 'page_label': '57'} page content
# Page 57 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 57, 'page_label': '58'} page content
# Page 58 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 58, 'page_label': '59'} page content
# Page 59 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 59, 'page_label': '60'} page content
# Page 60 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 60, 'page_label': '61'} page content
# Page 61 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 61, 'page_label': '62'} page content
# Page 62 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 62, 'page_label': '63'} page content
# Page 63 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 63, 'page_label': '64'} page content
# Page 64 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 64, 'page_label': '65'} page content
# Page 65 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 65, 'page_label': '66'} page content
# Page 66 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 66, 'page_label': '67'} page content
# Page 67 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 67, 'page_label': '68'} page content
# Page 68 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 68, 'page_label': '69'} page content
# Page 69 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 69, 'page_label': '70'} page content
# Page 70 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 70, 'page_label': '71'} page content
# Page 71 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 71, 'page_label': '72'} page content
# Page 72 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 72, 'page_label': '73'} page content
# Page 73 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 73, 'page_label': '74'} page content
# Page 74 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 74, 'page_label': '75'} page content
# Page 75 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 75, 'page_label': '76'} page content
# Page 76 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 76, 'page_label': '77'} page content
# Page 77 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 77, 'page_label': '78'} page content
# Page 78 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 78, 'page_label': '79'} page content
# Page 79 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 79, 'page_label': '80'} page content
# Page 80 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 80, 'page_label': '81'} page content
# Page 81 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 81, 'page_label': '82'} page content
# Page 82 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 82, 'page_label': '83'} page content
# Page 83 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 83, 'page_label': '84'} page content
# Page 84 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 84, 'page_label': '85'} page content
# Page 85 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 85, 'page_label': '86'} page content
# Page 86 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 86, 'page_label': '87'} page content
# Page 87 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 87, 'page_label': '88'} page content
# Page 88 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 88, 'page_label': '89'} page content
# Page 89 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 89, 'page_label': '90'} page content
# Page 90 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 90, 'page_label': '91'} page content
# Page 91 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 91, 'page_label': '92'} page content
# Page 92 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 92, 'page_label': '93'} page content
# Page 93 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 93, 'page_label': '94'} page content
# Page 94 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 94, 'page_label': '95'} page content
# Page 95 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 95, 'page_label': '96'} page content
# Page 96 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 96, 'page_label': '97'} page content
# Page 97 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 97, 'page_label': '98'} page content
# Page 98 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 98, 'page_label': '99'} page content
# Page 99 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 99, 'page_label': '100'} page content
# Page 100 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 100, 'page_label': '101'} page content
# Page 101 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 101, 'page_label': '102'} page content
# Page 102 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 102, 'page_label': '103'} page content
# Page 103 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 103, 'page_label': '104'} page content
# Page 104 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 104, 'page_label': '105'} page content
# Page 105 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 105, 'page_label': '106'} page content
# Page 106 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 106, 'page_label': '107'} page content
# Page 107 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 107, 'page_label': '108'} page content
# Page 108 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 108, 'page_label': '109'} page content
# Page 109 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 109, 'page_label': '110'} page content
# Page 110 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 110, 'page_label': '111'} page content
# Page 111 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 111, 'page_label': '112'} page content
# Page 112 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 112, 'page_label': '113'} page content
# Page 113 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 113, 'page_label': '114'} page content
# Page 114 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 114, 'page_label': '115'} page content
# Page 115 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 115, 'page_label': '116'} page content
# Page 116 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 116, 'page_label': '117'} page content
# Page 117 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 117, 'page_label': '118'} page content
# Page 118 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 118, 'page_label': '119'} page content
# Page 119 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 119, 'page_label': '120'} page content
# Page 120 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 120, 'page_label': '121'} page content
# Page 121 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 121, 'page_label': '122'} page content
# Page 122 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 122, 'page_label': '123'} page content
# Page 123 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 123, 'page_label': '124'} page content
# Page 124 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 124, 'page_label': '125'} page content
# Page 125 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 125, 'page_label': '126'} page content
# Page 126 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 126, 'page_label': '127'} page content
# Page 127 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 127, 'page_label': '128'} page content
# Page 128 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 128, 'page_label': '129'} page content
# Page 129 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 129, 'page_label': '130'} page content
# Page 130 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 130, 'page_label': '131'} page content
# Page 131 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 131, 'page_label': '132'} page content
# Page 132 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 132, 'page_label': '133'} page content
# Page 133 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 133, 'page_label': '134'} page content
# Page 134 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 134, 'page_label': '135'} page content
# Page 135 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 135, 'page_label': '136'} page content
# Page 136 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 136, 'page_label': '137'} page content
# Page 137 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 137, 'page_label': '138'} page content
# Page 138 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 138, 'page_label': '139'} page content
# Page 139 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 139, 'page_label': '140'} page content
# Page 140 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 140, 'page_label': '141'} page content
# Page 141 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 141, 'page_label': '142'} page content
# Page 142 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 142, 'page_label': '143'} page content
# Page 143 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 143, 'page_label': '144'} page content
# Page 144 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 144, 'page_label': '145'} page content
# Page 145 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 145, 'page_label': '146'} page content
# Page 146 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 146, 'page_label': '147'} page content
# Page 147 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 147, 'page_label': '148'} page content
# Page 148 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 148, 'page_label': '149'} page content
# Page 149 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 149, 'page_label': '150'} page content
# Page 150 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 150, 'page_label': '151'} page content
# Page 151 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 151, 'page_label': '152'} page content
# Page 152 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 152, 'page_label': '153'} page content
# Page 153 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 153, 'page_label': '154'} page content
# Page 154 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 154, 'page_label': '155'} page content
# Page 155 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 155, 'page_label': '156'} page content
# Page 156 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 156, 'page_label': '157'} page content
# Page 157 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 157, 'page_label': '158'} page content
# Page 158 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 158, 'page_label': '159'} page content
# Page 159 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 159, 'page_label': '160'} page content
# Page 160 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 160, 'page_label': '161'} page content
# Page 161 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 161, 'page_label': '162'} page content
# Page 162 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 162, 'page_label': '163'} page content
# Page 163 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 163, 'page_label': '164'} page content
# Page 164 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 164, 'page_label': '165'} page content
# Page 165 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 165, 'page_label': '166'} page content
# Page 166 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 166, 'page_label': '167'} page content
# Page 167 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 167, 'page_label': '168'} page content
# Page 168 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 168, 'page_label': '169'} page content
# Page 169 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 169, 'page_label': '170'} page content
# Page 170 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 170, 'page_label': '171'} page content
# Page 171 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 171, 'page_label': '172'} page content
# Page 172 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 172, 'page_label': '173'} page content
# Page 173 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 173, 'page_label': '174'} page content
# Page 174 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 174, 'page_label': '175'} page content
# Page 175 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 175, 'page_label': '176'} page content
# Page 176 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 176, 'page_label': '177'} page content
# Page 177 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 177, 'page_label': '178'} page content
# Page 178 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 178, 'page_label': '179'} page content
# Page 179 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 179, 'page_label': '180'} page content
# Page 180 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 180, 'page_label': '181'} page content
# Page 181 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 181, 'page_label': '182'} page content
# Page 182 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 182, 'page_label': '183'} page content
# Page 183 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 183, 'page_label': '184'} page content
# Page 184 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 184, 'page_label': '185'} page content
# Page 185 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 185, 'page_label': '186'} page content
# Page 186 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 186, 'page_label': '187'} page content
# Page 187 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 187, 'page_label': '188'} page content
# Page 188 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 188, 'page_label': '189'} page content
# Page 189 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 189, 'page_label': '190'} page content
# Page 190 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 190, 'page_label': '191'} page content
# Page 191 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 191, 'page_label': '192'} page content
# Page 192 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 192, 'page_label': '193'} page content
# Page 193 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 193, 'page_label': '194'} page content
# Page 194 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 194, 'page_label': '195'} page content
# Page 195 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 195, 'page_label': '196'} page content
# Page 196 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 196, 'page_label': '197'} page content
# Page 197 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 197, 'page_label': '198'} page content
# Page 198 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 198, 'page_label': '199'} page content
# Page 199 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 199, 'page_label': '200'} page content
# Page 200 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 200, 'page_label': '201'} page content
# Page 201 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 201, 'page_label': '202'} page content
# Page 202 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 202, 'page_label': '203'} page content
# Page 203 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 203, 'page_label': '204'} page content
# Page 204 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 204, 'page_label': '205'} page content
# Page 205 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 205, 'page_label': '206'} page content
# Page 206 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 206, 'page_label': '207'} page content
# Page 207 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 207, 'page_label': '208'} page content
# Page 208 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 208, 'page_label': '209'} page content
# Page 209 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 209, 'page_label': '210'} page content
# Page 210 char count: 0
# page details page_content='' metadata={'producer': 'jsPDF 2.4.0', 'creator': 'PyPDF', 'creationdate': '2023-06-16T12:36:28+05:30', 'source': 'data/pdf/data.pdf', 'total_pages': 211, 'page': 210, 'page_label': '211'} page content
# Page 211 char count: 0
# Created 0 chunks
